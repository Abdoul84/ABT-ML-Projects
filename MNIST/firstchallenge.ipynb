# %%
pip install tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow in /Users/moz/Library/Python/3.9/lib/python/site-packages (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorflow) (4.25.3)
# Requirement already satisfied: setuptools in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow) (58.0.4)
# Requirement already satisfied: six>=1.12.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorflow) (4.9.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorflow) (0.36.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorflow) (1.62.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorflow) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow) (0.37.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.28.1)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.5.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from markdown>=2.6.8->tensorboard<2.16,>=2.15->tensorflow) (7.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow) (2.1.5)
# Requirement already satisfied: zipp>=0.5 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.16,>=2.15->tensorflow) (3.17.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/moz/Library/Python/3.9/lib/python/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
import joblib

# %%
# Set random seeds for reproducibility
SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.15.0

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop columns and rows with all null values
df.dropna(axis='columns', how='all', inplace=True)
df.dropna(inplace=True)
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %%
# Map the values in 'koi_disposition' to 'YES' and 'NO'
df['koi_disposition'] = df['koi_disposition'].map({
    'FALSE POSITIVE': 'NO',
    'CANDIDATE': 'NO',
    'CONFIRMED': 'YES'
})

# Verify the mapping was successful
print(df['koi_disposition'].unique())
# Out:
# ['YES' 'NO']

# %%
# Verify that the mapping was successful and check the data types
print(df['koi_disposition'].unique())
print(df['koi_disposition'].dtype)
# Out:
# ['YES' 'NO']
# object

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.
selected_features = df[['koi_fpflag_nt', 'koi_fpflag_ss', 'koi_fpflag_co',
       'koi_fpflag_ec', 'koi_period', 'koi_period_err1', 'koi_period_err2',
       'koi_time0bk', 'koi_time0bk_err1', 'koi_time0bk_err2', 'koi_impact',
       'koi_impact_err1', 'koi_impact_err2', 'koi_duration',
       'koi_duration_err1', 'koi_duration_err2', 'koi_depth', 'koi_depth_err1',
       'koi_depth_err2', 'koi_prad', 'koi_prad_err1', 'koi_prad_err2',
       'koi_teq', 'koi_insol', 'koi_insol_err1', 'koi_insol_err2',
       'koi_model_snr', 'koi_tce_plnt_num', 'koi_steff', 'koi_steff_err1',
       'koi_steff_err2', 'koi_slogg', 'koi_slogg_err1', 'koi_slogg_err2',
       'koi_srad', 'koi_srad_err1', 'koi_srad_err2', 'ra', 'dec',
       'koi_kepmag']]
selected_features.head()
# Out:
#    koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0              0              0              0              0   54.418383
# 1              0              1              0              0   19.899140
# 2              0              1              0              0    1.736952
# 3              0              0              0              0    2.525592
# 4              0              0              0              0    4.134435
#
#    koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 0     2.479000e-04    -2.479000e-04   162.513840          0.003520
# 1     1.490000e-05    -1.490000e-05   175.850252          0.000581
# 2     2.630000e-07    -2.630000e-07   170.307565          0.000115
# 3     3.760000e-06    -3.760000e-06   171.595550          0.001130
# 4     1.050000e-05    -1.050000e-05   172.979370          0.001900
#
#    koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0         -0.003520  ...             -81      4.467           0.064
# 1         -0.000581  ...            -176      4.544           0.044
# 2         -0.000115  ...            -174      4.564           0.053
# 3         -0.001130  ...            -211      4.438           0.070
# 4         -0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 40 columns]

# %%
#Define feature matrix X and target vector y
X = selected_features
y = df['koi_disposition']

# %%
# Encode the target labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
# Split the data into training and testing sets with stratification
X_train, X_test, y_train, y_test = train_test_split(x, y_encoded, test_size=0.3, random_state=SEED, stratify=y_encoded)

# %%
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 1039              0              0              0              0   34.173216
# 4589              0              0              1              1    5.243319
# 2460              0              0              0              0    6.510030
# 3409              0              0              1              0    1.190874
# 1983              0              0              0              0    4.603575
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 1039         0.000120        -0.000120   137.788620          0.002910
# 4589         0.000092        -0.000092   132.785900          0.015200
# 2460         0.000013        -0.000013   172.915880          0.001540
# 3409         0.000013        -0.000013   131.718380          0.007800
# 1983         0.000005        -0.000005   171.840124          0.000813
#
#       koi_time0bk_err2  ...  koi_slogg  koi_slogg_err1  koi_slogg_err2  \
# 1039         -0.002910  ...      4.573           0.010          -0.090
# 4589         -0.015200  ...      4.613           0.035          -0.105
# 2460         -0.001540  ...      4.327           0.149          -0.182
# 3409         -0.007800  ...      4.464           0.105          -0.105
# 1983         -0.000813  ...      4.602           0.014          -0.046
#
#       koi_srad  koi_srad_err1  koi_srad_err2         ra        dec  \
# 1039     0.834          0.077         -0.026  288.37250  47.933559
# 4589     0.735          0.123         -0.057  291.82629  41.717300
# 2460     1.153          0.310         -0.207  282.11133  42.354500
# 3409     0.888          0.122         -0.100  294.59283  45.287720
# 1983     0.741          0.039         -0.030  297.35400  41.300049
#
#       koi_kepmag  koi_disposition
# 1039      13.733        CONFIRMED
# 4589      15.196   FALSE POSITIVE
# 2460      14.825        CONFIRMED
# 3409      15.280   FALSE POSITIVE
# 1983      12.970        CONFIRMED
#
# [5 rows x 41 columns]

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale features using MinMaxScaler and encode the labels using one-hot encoding
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

y_train_categorical = to_categorical(y_train)
y_test_categorical = to_categorical(y_test)

# %%
# # Step 1: Label-encode the data set
# label_encoder = LabelEncoder()

# encoded_y_train = label_encoder.fit_transform(y_train)
# encoded_y_test = label_encoder.transform(y_test)

# %%
# # Step 2: Convert encoded labels to one-hot-encoding
# y_train_categorical = to_categorical(encoded_y_train)
# y_test_categorical = to_categorical(encoded_y_test)

# %% [markdown]
# # Train the Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential([
    Dense(units=128, activation='relu', input_shape=(X_train_scaled.shape[1],)),
    Dropout(0.3),
    Dense(units=64, activation='relu'),
    Dropout(0.3),
    Dense(units=32, activation='relu'),
    Dense(units=3, activation='softmax')
])

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               4100
#
#  dense_1 (Dense)             (None, 100)               10100
#
#  dense_2 (Dense)             (None, 2)                 202
#
# =================================================================
# Total params: 14402 (56.26 KB)
# Trainable params: 14402 (56.26 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=40,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/40
# 153/153 - 1s - loss: 0.3867 - accuracy: 0.7956 - 1s/epoch - 8ms/step
# Epoch 2/40
# 153/153 - 0s - loss: 0.3203 - accuracy: 0.8279 - 165ms/epoch - 1ms/step
# Epoch 3/40
# 153/153 - 0s - loss: 0.3172 - accuracy: 0.8367 - 162ms/epoch - 1ms/step
# Epoch 4/40
# 153/153 - 0s - loss: 0.3070 - accuracy: 0.8434 - 163ms/epoch - 1ms/step
# Epoch 5/40
# 153/153 - 0s - loss: 0.3000 - accuracy: 0.8514 - 159ms/epoch - 1ms/step
# Epoch 6/40
# 153/153 - 0s - loss: 0.2961 - accuracy: 0.8520 - 165ms/epoch - 1ms/step
# Epoch 7/40
# 153/153 - 0s - loss: 0.2890 - accuracy: 0.8559 - 158ms/epoch - 1ms/step
# Epoch 8/40
# 153/153 - 0s - loss: 0.2867 - accuracy: 0.8645 - 153ms/epoch - 1ms/step
# Epoch 9/40
# 153/153 - 0s - loss: 0.2832 - accuracy: 0.8594 - 154ms/epoch - 1ms/step
# Epoch 10/40
# 153/153 - 0s - loss: 0.2756 - accuracy: 0.8745 - 153ms/epoch - 1ms/step
# Epoch 11/40
# 153/153 - 0s - loss: 0.2760 - accuracy: 0.8667 - 154ms/epoch - 1ms/step
# Epoch 12/40
# 153/153 - 0s - loss: 0.2721 - accuracy: 0.8727 - 153ms/epoch - 999us/step
# Epoch 13/40
# 153/153 - 0s - loss: 0.2719 - accuracy: 0.8725 - 155ms/epoch - 1ms/step
# Epoch 14/40
# 153/153 - 0s - loss: 0.2642 - accuracy: 0.8776 - 176ms/epoch - 1ms/step
# Epoch 15/40
# 153/153 - 0s - loss: 0.2598 - accuracy: 0.8798 - 184ms/epoch - 1ms/step
# Epoch 16/40
# 153/153 - 0s - loss: 0.2582 - accuracy: 0.8790 - 211ms/epoch - 1ms/step
# Epoch 17/40
# 153/153 - 1s - loss: 0.2552 - accuracy: 0.8845 - 518ms/epoch - 3ms/step
# Epoch 18/40
# 153/153 - 0s - loss: 0.2593 - accuracy: 0.8821 - 184ms/epoch - 1ms/step
# Epoch 19/40
# 153/153 - 0s - loss: 0.2495 - accuracy: 0.8872 - 182ms/epoch - 1ms/step
# Epoch 20/40
# 153/153 - 0s - loss: 0.2468 - accuracy: 0.8874 - 179ms/epoch - 1ms/step
# Epoch 21/40
# 153/153 - 0s - loss: 0.2501 - accuracy: 0.8856 - 184ms/epoch - 1ms/step
# Epoch 22/40
# 153/153 - 0s - loss: 0.2455 - accuracy: 0.8870 - 160ms/epoch - 1ms/step
# Epoch 23/40
# 153/153 - 0s - loss: 0.2455 - accuracy: 0.8878 - 179ms/epoch - 1ms/step
# Epoch 24/40
# 153/153 - 0s - loss: 0.2442 - accuracy: 0.8905 - 176ms/epoch - 1ms/step
# Epoch 25/40
# 153/153 - 0s - loss: 0.2323 - accuracy: 0.8958 - 160ms/epoch - 1ms/step
# Epoch 26/40
# 153/153 - 0s - loss: 0.2385 - accuracy: 0.8911 - 171ms/epoch - 1ms/step
# Epoch 27/40
# 153/153 - 0s - loss: 0.2407 - accuracy: 0.8921 - 151ms/epoch - 990us/step
# Epoch 28/40
# 153/153 - 0s - loss: 0.2378 - accuracy: 0.8929 - 151ms/epoch - 986us/step
# Epoch 29/40
# 153/153 - 0s - loss: 0.2349 - accuracy: 0.8954 - 153ms/epoch - 999us/step
# Epoch 30/40
# 153/153 - 0s - loss: 0.2289 - accuracy: 0.8970 - 159ms/epoch - 1ms/step
# Epoch 31/40
# 153/153 - 0s - loss: 0.2350 - accuracy: 0.8894 - 152ms/epoch - 993us/step
# Epoch 32/40
# 153/153 - 0s - loss: 0.2345 - accuracy: 0.8952 - 152ms/epoch - 996us/step
# Epoch 33/40
# 153/153 - 0s - loss: 0.2325 - accuracy: 0.8900 - 152ms/epoch - 991us/step
# Epoch 34/40
# 153/153 - 0s - loss: 0.2256 - accuracy: 0.8986 - 151ms/epoch - 984us/step
# Epoch 35/40
# 153/153 - 0s - loss: 0.2267 - accuracy: 0.9003 - 152ms/epoch - 995us/step
# Epoch 36/40
# 153/153 - 0s - loss: 0.2214 - accuracy: 0.8992 - 187ms/epoch - 1ms/step
# Epoch 37/40
# 153/153 - 0s - loss: 0.2284 - accuracy: 0.8960 - 151ms/epoch - 986us/step
# Epoch 38/40
# 153/153 - 0s - loss: 0.2227 - accuracy: 0.8992 - 152ms/epoch - 996us/step
# Epoch 39/40
# 153/153 - 0s - loss: 0.2209 - accuracy: 0.8964 - 150ms/epoch - 982us/step
# Epoch 40/40
# 153/153 - 0s - loss: 0.2248 - accuracy: 0.8964 - 152ms/epoch - 990us/step

# %%
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 55/55 - 0s - loss: 0.2198 - accuracy: 0.9079 - 294ms/epoch - 5ms/step
# Normal Neural Network - Loss: 0.21980665624141693, Accuracy: 0.9078947305679321

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# Assuming y is your target variable

y = np.array(y).ravel()

# %%
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.svm import SVC

# Assuming X and yy are defined and are your features and target variables
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

param_grid = {'C': [1, 10, 100, 1000], 'gamma': [0.001, 0.0001], 'kernel': ['linear', 'rbf']}
grid = GridSearchCV(SVC(), param_grid, refit=True, verbose=3)

# Fit the grid search to the data
grid.fit(X_train, y_train)

# Optional: Extract and use the best parameters or the best estimator
# print(grid.best_params_)
# best_estimator = grid.best_estimator_
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(grid.best_params_)
#       2 print(grid.best_score_)
#
# NameError: name 'grid' is not defined

# %% [markdown]
# # Save the Model

# %%
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'model_1.sav'
joblib.dump(model_1, filename)
